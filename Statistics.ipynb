# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../adresses_31.db")
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 50)

df = pd.read_sql('SELECT * FROM adress31', conn)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
sns.set(style="whitegrid", color_codes=True)

# %%
# %matplotlib inline
plt.figure(figsize=(10, 16))
plot = df['beruf'].value_counts()[:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("berufe_titel.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['bezirk'].value_counts()[:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("bezirke.png")

# %%
df = pd.read_sql('SELECT * FROM census_merge', conn)

# %%
df.head()
# Out:
#    index index_x  vorname    nachname geboren geburtsdatum       geburtsort_x  \
# 0      0     0.0   Trudel  Odenheimer    None   15.06.1822         Heidelberg
# 1      1     1.0    Horst      Weigel    None   09.12.1838    Berlin-Neukölln
# 2      2     2.0     Karl        Fels    None   19.12.1839          Magdeburg
# 3      3     3.0    Luise        Fels    None   18.05.1839          Magdeburg
# 4      4     5.0  Susanne   Heynemann    None   19.06.1839  Berlin-Zehlendorf
#
#              adresse       zusatz      bezirk   Longitude   Latitude  \
# 0    Prinzenstr. 128         None    Biesdorf  13.3860112   52.44394
# 1        Ossastr. 45         None    Neukölln  13.4378783  52.486611
# 2    Usedomer Str. 5  III. rechts     Wedding  13.3897366  52.539979
# 3    Usedomer Str. 5  III. rechts     Wedding  13.3897366  52.539979
# 4  Freisinger Str. 4         None  Schöneberg  13.3466048  52.491113
#
#                                       census_geocode   x_mercator_census  \
# ...

# %%
plt.figure(figsize=(10, 16))
plot = df['geburtsort_x'].value_counts()[:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("geburtsort.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['todesort'].value_counts()[1:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("todesort.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['deportationsziel'].value_counts()[:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("deportationsziel.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['emigration_1'].value_counts()[1:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("emigration.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['inhaftierung_1'].value_counts()[1:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("emigration.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['deportationsdatum'].value_counts()[1:20].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("deportationsdatum.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['schicksal'].value_counts()[:5].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("schicksal.png")

# %%
plt.figure(figsize=(10, 16))
plot = df['emigration_1_zeitpunkt'].value_counts()[1:11].plot(kind='barh')
fig = plot.get_figure()
fig.savefig("date_emigration.png")
